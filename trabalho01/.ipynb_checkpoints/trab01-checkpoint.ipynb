# %% [markdown]
# # Avaliação 08 - Implementação de Filtros Digitais
#
# ---
#
# ### Projeto 2: Butterworth por Transformação Bilinear
#
# ENGC63 - 2021.2
#
# João Carneiro e Osmar Oliveira

# %% [markdown]
# ## Imports

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.fft import fft, fftfreq
from scipy.io.wavfile import read, write
from IPython.display import display, Math, Audio

# %% [markdown]
# ## Funções Auxiliares

# %%
# Imprime float em notação científica
def print_scientific(number):
    exp = np.floor(np.log10(np.abs(number))).astype(int)
    num = number * 10.0**(-exp - 1)
    display(Math(r"{0} \times 10^{{{1}}}".format(num, exp+1)))

# Reduz precisão da mantissa de um float
def reduce_precision(num, precision):
    exp = np.floor(np.log10(np.abs(num))).astype(int)
    num = np.around(num, exp+precision)
    return num

# %% [markdown]
# ## Filtro Discreto Passa-Baixas
#
# Transformação bilinear de um filtro Butterworth

# %% [markdown]
# ### Filtro Butterworth

# %%
order = 6          # Ordem do Butterworth
fs = 44100         # Freq de amostragem para audio de 20kHz
wc = 2*np.pi/3     # Freq de corte em rad/amostras (cutoff)

fc = fs*wc/(2*np.pi) # Freq de corte em Hz
Wc = 2*np.pi*fc      # Freq angular de corte [rad/s]

# Cria filtro Butterworth:
filts = signal.lti(*signal.butter(order, Wc, btype='lowpass', analog=True, output='ba'))

# %% [markdown]
# ### Transformação Bilinear

# %%
# Converte Butterworth para filtro discreto por Transformação Linear:
filtz = signal.dlti(*signal.bilinear(filts.num, filts.den, fs=fs))
wz, hz = signal.freqz(filtz.num, filtz.den)
ws, hs = signal.freqs(filts.num, filts.den, worN=fs*wz)

# %% [markdown]
# ### Respostas em frequência

# %%
plt.plot(wz*fs/(2*np.pi), 20*np.log10(np.abs(hs)))
plt.axvline(x=fc, color='green', ls='--', label='$f_c$ = {} Hz'.format(round(fc)), alpha=0.7)
plt.legend()
plt.title('Butterworth')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

# %%
plt.plot(wz*fs/(2*np.pi), 20*np.log10(np.abs(hz)))
plt.axvline(x=fc, color='green', ls='--', label='$f_c$ = {} Hz'.format(round(fc)), alpha=0.7)
plt.legend()
plt.title('Transformação Bilinear')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

# %% [markdown]
# ## Função para Forma Direta I

# %%
# Encontra saída pela Forma Direta I
def direct_i(input_x, filtz):
    x = input_x.copy()
    input_size = len(x)

    b = filtz.num.copy()
    a = filtz.den.copy()

    M = len(b) - 1
    N = len(a) - 1

    y = np.zeros(input_size)

    # Função para retornar 0 em caso de índice inválido
    def get_value(array, index):
        try:
            return array[index]
        except:
            return 0

    # Percorre por toda entrada
    for n in range(input_size):
        # Somatórios resultantes da Forma Direta I
        for i in range(M+1):
            y[n] += b[i] * get_value(x, n - i)
        for j in range(1, N+1):
            y[n] -= a[j] * get_value(y, n - j)
    
    return y

# %% [markdown]
# ## Função para Forma em Cascata

# %%
# Encontra saída pela Forma em Cascata
def cascade(input_x, filtz):
    x = input_x.copy()
    b = filtz.num.copy()
    a = filtz.den.copy()

    # Converte TF para SOS (seções de 2a ordem)
    sos = signal.tf2sos(b, a)

    # Filtra entrada pela sequência em cascata das funções
    y = signal.sosfilt(sos, x)

    return y

# %% [markdown]
# ## Cria filtros com menos casas decimais

# %%
# Calcula resposta em frequência
wz1, hz1 = signal.freqz(filtz.num, filtz.den)

filtz_5prec = signal.dlti(filtz.num, filtz.den)

for i, val in enumerate(filtz_5prec.num):
    filtz_5prec.num[i] = reduce_precision(val, 5)
for i, val in enumerate(filtz_5prec.den):
    filtz_5prec.den[i] = reduce_precision(val, 5)

wz2, hz2 = signal.freqz(filtz_5prec.num, filtz_5prec.den)

filtz_2prec = signal.dlti(filtz.num, filtz.den)

for i, val in enumerate(filtz_2prec.num):
    filtz_2prec.num[i] = reduce_precision(val, 2)
for i, val in enumerate(filtz_2prec.den):
    filtz_2prec.den[i] = reduce_precision(val, 2)

wz3, hz3 = signal.freqz(filtz_2prec.num, filtz_2prec.den)

# %% [markdown]
# # Transformação $Z^{-1} = -z^{-1}$

# %%
def first_transf_tf(b, a):
    b1 = b.copy()
    a1 = a.copy()
    for idx, val in enumerate(b1):
        if idx % 2 == b1.shape[0] % 2:
            b1[idx] = -val
    for idx, val in enumerate(a1):
        if idx % 2 == a1.shape[0] % 2:
            a1[idx] = -val
    return b1, a1


filtz_ft = signal.dlti(*first_transf_tf(filtz.num, filtz.den))

# %% [markdown]
# # Transformação $Z^{-1} = z^{-2}$

# %%
def second_transf_tf(b, a):
    newList = []
    for idx, val in enumerate(b):
        newList.append(val)
        newList.append(0)
    b1 = np.array(newList[:-1])
    newList = []
    for idx, val in enumerate(a):
        newList.append(val)
        newList.append(0)
    a1 = np.array(newList[:-1])

    return b1, a1


filtz_st =  signal.dlti(*second_transf_tf(filtz.num, filtz.den))

# %% [markdown]
# # Transformação $Z^{-1} = -z^{-2}$

# %%
def third_transf_tf(b, a):
    b_1, a_1 = first_transf_tf(b, a)
    b_2, a_2 = second_transf_tf(b_1, a_1)
    return b_2, a_2

filtz_tt = signal.dlti(*third_transf_tf(filtz.num, filtz.den))

# %% [markdown]
# ## Carrega áudio de entrada

# %%
(freq, x) = read("trumpet.wav")
N = x.shape[0]
t = np.linspace(0, N/freq, N)

xf = fft(x)
f = fftfreq(N, 1/fs)[:N//2]

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(t, x)
plt.title("Sinal de Entrada")
plt.xlabel("Tempo [s]")
plt.show()

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(xf[0:N//2]))
plt.title("Na Frequencia")
plt.xlabel("Freq [Hz]")
plt.show()

Audio("trumpet.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Adiciona componente de alta frequência

# %%
white = np.random.normal(0, 1, N)                     # Gera ruído branco
hi_b, hi_a = signal.butter(2, 2*fc/fs, btype='high')  # Filtro digital passa alta
noise = signal.lfilter(hi_b, hi_a, white)             # Transforma ruído branco em alta freq
                                         
x_amp = x.max()
noise_amp = noise.max()
noise = noise * (x_amp/noise_amp)/8  # Amplifica ruído

x = x + noise
xf = fft(x)

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(t, x)
plt.title("Sinal de Entrada")
plt.xlabel("Tempo [s]")
plt.show()

plt.figure(figsize=(10, 4), dpi=100)
plt.specgram(direct_infi, Fs=fs, sides='onesided')
plt.title('Espectrograma da entrada')
plt.ylabel('Freq [Hz]')
plt.xlabel('Tempo [s]')

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(xf[0:N//2]))
plt.title("Na Frequencia")
plt.xlabel("Freq [Hz]")
plt.show()

Audio(x, rate=freq)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Filtragem

# %% [markdown]
# ### Direto com precisão infinita

# %%
direct_infi = direct_i(x, filtz)

plt.figure(figsize=(10, 8), dpi=100)
plt.subplot(2, 2, 1)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.plot(wz1*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz1)), label=r'$|H_z(e^{j \omega})|$')
ax = plt.axis()
ax = [0.1, ax[1], -100, ax[3]]
plt.axis(ax)
plt.title('Precisão infinita')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()

plt.subplot(2, 2, 2)
plt.specgram(direct_infi, Fs=fs, sides='onesided')
plt.title('Espectrograma resultante')
plt.ylabel('Freq [Hz]')
plt.xlabel('Tempo [s]')

plt.subplot(2, 2, (3, 4))
plt.plot(f, 2.0/N * np.abs(fft(direct_infi)[0:N//2]))
plt.title("Filtragem Direta com Precisão Infinita")
plt.xlabel("Freq [Hz]")
plt.show()

print(filtz)

Audio(direct_infi, rate=freq)
# Out:
# TransferFunctionDiscrete(
# array([0.03391037, 0.20346223, 0.50865558, 0.67820744, 0.50865558,
#        0.20346223, 0.03391037]),
# array([1.        , 0.17415911, 0.78901525, 0.08259211, 0.11713691,
#        0.00554934, 0.0018111 ]),
# dt: True
# )
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Direto com precisão de 5 casas decimais

# %%
direct_5 = direct_i(x, filtz_5prec)

plt.figure(figsize=(10, 8), dpi=100)
plt.subplot(2, 2, 1)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.plot(wz2*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz2)), label=r'$|H_z(e^{j \omega})|$')
plt.axis((ax))
plt.legend()
plt.title('Precisão Finita 5 casas decimais')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

print(filtz_5prec)

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(fft(direct_5)[0:N//2]))
plt.title("Filtragem Direta com precisão de 5 casas")
plt.xlabel("Freq [Hz]")
plt.show()

Audio(direct_5, rate=freq)

# %% [markdown]
# ### Direto com precisão de 2 casas decimais

# %%
direct_2 = direct_i(x, filtz_2prec)

plt.plot(wz3*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz3)), label=r'$|H_z(e^{j \omega})|$')
plt.axis(ax)
plt.legend()
plt.title('Precisão Finita 2 casas decimais')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

plt.subplot(2, 2, 2)
plt.specgram(direct_2, Fs=fs, sides='onesided')
plt.title('Espectrograma resultante')
plt.ylabel('Freq [Hz]')
plt.xlabel('Tempo [s]')

plt.subplot(2, 2, (3, 4))
plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(fft(direct_2)[0:N//2]))
plt.title("Filtragem Direta com precisão de 2 casas")
plt.xlabel("Freq [Hz]")
plt.show()

print(filtz_2prec)

Audio(direct_2, rate=freq)

# %% [markdown]
# ### Cascata com precisão infinita

# %%
cascade_infi = cascade(x, filtz)

plt.plot(wz1*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz1)), label=r'$|H_z(e^{j \omega})|$')
ax = plt.axis()
plt.title('Precisão infinita')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

print(filtz)

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(fft(cascade_infi)[0:N//2]))
plt.title("Filtragem Cascata com precisão infinita")
plt.xlabel('Freq [Hz]')
plt.show()

Audio(cascade_infi, rate=freq)

# %% [markdown]
# ### Cascata com precisão de 5 casas decimais

# %%
cascade_5 = cascade(x, filtz_5prec)

plt.plot(wz2*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz2)), label=r'$|H_z(e^{j \omega})|$')
plt.axis((ax))
plt.legend()
plt.title('Precisão Finita 5 casas decimais')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

print(filtz_5prec)

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(fft(cascade_5)[0:N//2]))
plt.title("Filtragem Cascata com precisão de 5 casas")
plt.xlabel('Freq [Hz]')
plt.show()

Audio(cascade_5, rate=freq)

# %% [markdown]
# ### Cascata com precisão de 2 casas decimais

# %%
cascade_2 = cascade(x, filtz_2prec)
print(filtz_2prec)

plt.plot(wz3*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz3)), label=r'$|H_z(e^{j \omega})|$')
plt.axis((ax))
plt.legend()
plt.title('Precisão Finita 2 casas decimais')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

print(filtz_2prec)

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(fft(cascade_2)[0:N//2]))
plt.title("Filtragem Cascata com precisão de 2 casas")
plt.xlabel('Freq [Hz]')
plt.show()

Audio(cascade_2, rate=freq)

# %% [markdown]
# ### Direto com Transformação $Z^{-1} = -z^{-1}$

# %%
trans1 = direct_i(x, filtz_ft)

wz, hz = signal.freqz(filtz_ft.num, filtz_ft.den)

plt.plot(wz*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz)), label=r'$|H_z(e^{j \omega})|$')
plt.legend()
plt.title(r'$ Z^{-1} = -z^{-1} $')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(fft(trans1)[0:N//2]))
plt.title("Filtro Direto com $Z^{-1} = -z^{-1}$")
plt.xlabel('Freq [Hz]')
plt.show()

Audio(trans1, rate=freq)

# %% [markdown]
# ### Direto com Transformação $Z^{-1} = z^{-2}$

# %%
trans2 = direct_i(x, filtz_st)

wz, hz = signal.freqz(filtz_st.num, filtz_st.den)

plt.plot(wz*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz)), label=r'$|H_z(e^{j \omega})|$')
plt.legend()
plt.title(r'$Z^{-1} = z^{-2}$')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(fft(trans2)[0:N//2]))
plt.title("Filtro Direto com $Z^{-1} = z^{-2}$")
plt.xlabel('Freq [Hz]')
plt.show()

Audio(trans2, rate=freq)

# %% [markdown]
# ### Direto com Transformação $Z^{-1} = -z^{-2}$

# %%
trans3 = direct_i(x, filtz_tt)

wz, hz = signal.freqz(filtz_tt.num, filtz_tt.den)

plt.plot(wz*1/(2*np.pi)*fs, 20*np.log10(np.abs(hz)), label=r'$|H_z(e^{j \omega})|$')
plt.legend()
plt.title(r'$Z^{-1} = -z^{-2}$')
plt.xlabel('Freq [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.show()

plt.figure(figsize=(10, 4), dpi=100)
plt.plot(f, 2.0/N * np.abs(fft(trans3)[0:N//2]))
plt.title("Filtro Direto com $Z^{-1} = -z^{-2}$")
plt.xlabel('Freq [Hz]')
plt.show()

Audio(trans3, rate=freq)
